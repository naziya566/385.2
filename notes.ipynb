# %% [markdown]
# Required Libraries:
# WIndows:
# Python
# Download
# Add python to your path - allows you to run python from terminal anywhere on computer
# pip  - for managing dependencies
# Terminal command:
# python -m ensurepip --upgrade-to-system

# %%
print('helooooo')
greet='Hello World'
print(greet[2])
print(greet[0:5])
type(greet)
# Out:
# helooooo
# l
# Hello
# str

# %%
tools=['laptop','Monitor','Keyboard','Mouse']
print(tools,1:3)
# Out:
#   Cell In[15], line 2
#     print(tools,1:3)
#                  ^
# SyntaxError: invalid syntax

# %%
Tools=['laptop','Monitor','Keyboard','Mouse']
print(Tools[1])
sublist=Tools[1:4]
print(sublist)
#reassighning
Tools[1]='Webcame'
print(Tools)
Tools.append('Desk')
print(Tools)
#Tools.insert(1:,'Head phones','Coffe mug')
Tools[1:1] = ['Headphones', 'Coffee mug']
Tools[1:1] = ['Headphones', 'Coffee mug']
total_items=len(Tools)
print(total_items)

print(Tools)
# ***ACT
# Initial guest list
guests = ["Alice", "Bob", "Charlie", "David", "Eve"]
print("Initial list:", guests)
guests.append('Frank')
print("Late Arrival:", guests)
guests.insert(0,'Grace')
print("VIP Priority:", guests)
#  **The Substitution:**  
#   **"Charlie"** cannot make it. Replace his name with **"Chuck"**.
guests [3]='Chuck'
print("The Substitution:", guests)
guests.remove('Chuck')
print("Security Issue:", guests)
Total_length=len(guests)
print(f'Total_length' Total_length)
# Out:
#   Cell In[57], line 32
#     print('Total_length' Total_length)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Numlist
num_list=[1,2,3,4,5]
print(num_list)
num_list.reverse()
print (num_list)

print(6+4)
print(6-4)
print(6*4)
print(6/4)
print(6//4)
print(6%4)
print(6**4)
print(9 % 6 % 2)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
# 10
# 2
# 24
# 1.5
# 1
# 2
# 1296
# 1
